# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the api library to add the invoice update method.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the invoice controller to add the update function.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the invoices page to include project filtering/grouping.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the invoice controller to manually fetch and attach contacts.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the backend controller to handle the includePaid parameter.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the invoice controller first.

# %%
// This is a placeholder for the tool call logic I will perform.
// I will edit the backend controller first.
